# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)

# %%
x = np.arange(0, 2, 0.01)
y = x

# %%
f = lambda x,y: np.maximum(x,y)
g = lambda x,y: np.log(np.exp(x) + np.exp(y))

# %%
X, Y = np.meshgrid(x, y)
Z = f(X, Y)
W = g(X, Y)

# %%
fig = plt.figure(figsize=(20, 10))
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
fig = plt.figure(figsize=(20, 10))
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, W, 50)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
fig = plt.figure(figsize=(20, 10))
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z)
ax.set_title('wireframe');

# %%
fig = plt.figure(figsize=(20, 10))
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, W)
ax.set_title('wireframe');

# %%
fig = plt.figure(figsize=(20, 20))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, linewidth=0, antialiased=False, cmap='coolwarm', edgecolor='black')
ax.set_title('surface')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
fig.tight_layout()
plt.savefig("f.svg")

# %%
fig = plt.figure(figsize=(20, 20))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, W, linewidth=0, antialiased=False, cmap='coolwarm', edgecolor='black')
ax.set_title('surface')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
fig.tight_layout()
plt.savefig("g.svg")
